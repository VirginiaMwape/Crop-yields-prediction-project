# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
import matplotlib as plt
import matplotlib.pyplot as plt
import datetime as dt
from scipy import stats
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=UserWarning)
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv('../input/crop-recommendation-dataset/Crop_recommendation.csv')
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-12-400c8bba0294> in <module>
# ----> 1 df=pd.read_csv('../input/crop-recommendation-dataset/Crop_recommendation.csv')
#       2 df.head()
#       3
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
# ...

# %% [markdown]
# Rain by month and year Total in Australia from BOM

# %%
rains_df = pd.read_csv ('C:/Users/Aldebaran/Downloads/final project/Data/latest.39177.csv')
#convert Date to datetime format
#covid_cases_df["Date"] = pd.to_datetime(covid_cases_df["Date"])
#covid_cases_df.head()

# %%
rains_df.describe()
# Out:
#               Year         Jan         Feb         Mar         Apr  \
# count   123.000000  123.000000  123.000000  123.000000  123.000000
# mean   1961.000000   77.934634   77.257967   59.994472   27.526179
# std      35.651087   28.415021   28.298126   24.403074   13.690323
# min    1900.000000   33.900000   22.220000   15.150000    4.880000
# 25%    1930.500000   59.965000   55.600000   42.840000   16.600000
# 50%    1961.000000   73.430000   78.480000   58.860000   26.010000
# 75%    1991.500000   93.525000   97.170000   74.880000   36.220000
# max    2022.000000  231.820000  152.150000  146.640000   72.250000
#
#               May         Jun         Jul         Aug         Sep         Oct  \
# count  122.000000  122.000000  122.000000  122.000000  122.000000  122.000000
# mean    25.108852   24.692131   21.338361   17.312459   16.012623   22.767705
# std     12.105717    9.976994    9.200618    6.519824    8.441489   11.547817
# ...

# %%
plt.figure(figsize=(24,10))
plt.subplot(1, 2, 1)
# sns.distplot(df_setosa['sepal_length'],kde=True,color='green',bins=20,hist_kws={'alpha':0.3})
sns.distplot(rains_df['Jan'],color="green",bins=15,hist_kws={'alpha':0.2})
plt.subplot(1, 2, 1)
sns.distplot(rains_df['Feb'],color="green",bins=15,hist_kws={'alpha':0.2})
plt.subplot(1, 2, 1)
sns.distplot(rains_df['Mar'],color="green",bins=15,hist_kws={'alpha':0.2})
plt.subplot(1, 2, 1)
sns.distplot(rains_df['Apr'],color="yellow",bins=15,hist_kws={'alpha':0.2})
plt.subplot(1, 2, 1)
sns.distplot(rains_df['May'],color="black",bins=15,hist_kws={'alpha':0.2})
plt.subplot(1, 2, 1)
sns.distplot(rains_df['Jun'],color="black",bins=15,hist_kws={'alpha':0.2})
plt.subplot(1, 2, 1)
sns.distplot(rains_df['Jul'],color="black",bins=15,hist_kws={'alpha':0.2})
plt.subplot(1, 2, 1)
sns.distplot(rains_df['Aug'],color="black",bins=15,hist_kws={'alpha':0.2})
plt.subplot(1, 2, 1)
sns.distplot(rains_df['Sep'],color="black",bins=15,hist_kws={'alpha':0.2})
plt.subplot(1, 2, 1)
sns.distplot(rains_df['Oct'],color="black",bins=15,hist_kws={'alpha':0.2})
plt.subplot(1, 2, 1)
sns.distplot(rains_df['Nov'],color="yellow",bins=15,hist_kws={'alpha':0.2})
plt.subplot(1, 2, 1)
sns.distplot(rains_df['Dec'],color="green",bins=15,hist_kws={'alpha':0.2})
# Out:
# <AxesSubplot:xlabel='Dec', ylabel='Density'>

# %%
rains_df['Total'] = rains_df.iloc[:, 1:].sum(axis=1)

# %%
rains_df.head()
# Out:
#    Year    Jan    Feb    Mar    Apr    May    Jun    Jul    Aug    Sep    Oct  \
# 0  1900  53.59  25.42  69.86  42.40  34.18  32.39  34.31  15.81  15.10   8.24
# 1  1901  43.88  94.28  85.99  23.84  18.11  24.19  18.19  26.55  15.27  17.32
# 2  1902  80.77  51.86  21.70   4.88   9.43  14.90   9.67  10.91  12.70  16.17
# 3  1903  65.86  47.16  84.16  50.75  28.16  21.64  23.22  16.01  32.44  20.99
# 4  1904  91.49  73.17  64.79  41.99  37.70  21.16  37.88  11.12  22.22  38.43
#
#      Nov    Dec   Total
# 0  19.18  25.52  376.00
# 1  14.85  22.45  404.92
# 2  30.59  55.94  319.52
# 3  38.52  91.37  520.28
# 4  17.57  48.31  505.83

# %%
rains_df['Mean'] = rains_df.iloc[:, 1:13].mean(axis=1)

# %%
rains_df.head()
# Out:
#    Year    Jan    Feb    Mar    Apr    May    Jun    Jul    Aug    Sep    Oct  \
# 0  1900  53.59  25.42  69.86  42.40  34.18  32.39  34.31  15.81  15.10   8.24
# 1  1901  43.88  94.28  85.99  23.84  18.11  24.19  18.19  26.55  15.27  17.32
# 2  1902  80.77  51.86  21.70   4.88   9.43  14.90   9.67  10.91  12.70  16.17
# 3  1903  65.86  47.16  84.16  50.75  28.16  21.64  23.22  16.01  32.44  20.99
# 4  1904  91.49  73.17  64.79  41.99  37.70  21.16  37.88  11.12  22.22  38.43
#
#      Nov    Dec   Total       Mean
# 0  19.18  25.52  376.00  31.333333
# 1  14.85  22.45  404.92  33.743333
# 2  30.59  55.94  319.52  26.626667
# 3  38.52  91.37  520.28  43.356667
# 4  17.57  48.31  505.83  42.152500

# %%
fig, ax = plt.subplots()
ax.plot(rains_df['Year'],rains_df['Total'])

ax.set(xlabel='1900 to 2020', ylabel='Rainfall (mm)',
       title='Nationwide total rainfall trend for more then a century')
ax.grid()
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot(rains_df['Year'],rains_df['Mean'])

ax.set(xlabel='1900 to 2020', ylabel='Rainfall (mm)',
       title='Nationwide mean rainfall trend for more then a century')
ax.grid()
plt.show()
